# %%
#!/afs/inf.ed.ac.uk/user/s14/s1413557/miniconda2/bin/python
from __future__ import print_function
from f4klib2 import *
movs = loadMovids()
movs_length = loadLengths()

# %%
# 5  Broken contX, FEIF bugs, Ghost Fish?
# 30 No detection
# 40 Ghost Fish
# 131 100% no contour
# 247420 giant1
# 48354 giant2
# 30598
#temppicka = np.arange(148701,173761)
temppicka = np.arange(30598,30695)
picker = temppicka[1]
picker = 5
movid = movs[picker]
#movid = movs[picker]
info, clip, hasContour, contour, fish_id, frames = loadVideo(movid,
                                                    print_info=True,
                                                    print_time=True)
# Out:
# Loading data took: 0:00:00.749887
# Using video_id: 000091a58183e0358d5c3f8716c8491a#201101151720
# Using movie, csv, sql paths:
# /afs/inf.ed.ac.uk/group/ug4-projects/s1413557/summaries/0/00/summary_000091a58183e0358d5c3f8716c8491a#201101151720.avi
# /afs/inf.ed.ac.uk/group/ug4-projects/s1413557/summaries/0/00/frame_info_000091a58183e0358d5c3f8716c8491a#201101151720.txt
# /afs/inf.ed.ac.uk/group/ug4-projects/s1413557/sqldump/0/00/000091a58183e0358d5c3f8716c8491a#201101151720.txt
# Video frame size: 320x240, camera_id: 37
# Total frames in video: 4716
# 4716 out of 4716, about 100% detection have a bounding box in sql.
# 841 out of 4716 total detection is rejected by FEIF, 3875 kept. Reject rate: 18%
# FEIF Runtime: 0:00:01.136183

# %%
h = 0
w = 15
d = 20
g = 1
t = h + d * w 
plotStuff(info, clip, hasContour, contour, movid, limit_lower=h, limit_upper=t, width=w, gap=g, classify=True)

# %%
clipv = VideoFileClip("/afs/inf.ed.ac.uk/user/s14/s1413557/Downloads/video_siteLanYu_camera1_201010240800.flv")

# %%
plt.figure(figsize=(12,8))
plt.imshow(clipv.get_frame(193.2))
plt.xticks([])
plt.yticks([])
string2 = contour[46]
points2 = getContour(string2,return_what="Original")
plt.scatter(points2[:,0],points2[:,1],s=0.2)
plt.axvline(203,linewidth=5, color='r', alpha=0.4)
plt.axvline(313,linewidth=5, color='r', alpha=0.4)
plt.axhline(7,linewidth=5, color='r', alpha=0.4)
plt.axhline(117,linewidth=5, color='r', alpha=0.4)
plt.show()

string2 = contour[46]
points2 = getContour(string2)
plt.imshow(clip[46])   
plt.xticks([])
plt.yticks([])
plt.scatter(points2[:,0],points2[:,1],s=5)
plt.axvline(9,                linewidth=1, color='r', alpha=0.4)
plt.axvline(10+info[46,1],linewidth=1, color='r', alpha=0.4)
plt.axhline(9,                linewidth=1, color='r', alpha=0.4)
plt.axhline(10+info[46,2],linewidth=1, color='r', alpha=0.4)
plt.show()

# %%
def printClassExamples():
    samp_vids = [343 ,638,6,5,13 ,146,153,408,408,5  ]
    samp_fram = [1000,80 ,0,0,136,301,290,60 ,1  ,177]
    
    plt.subplots(2,5,figsize=(15,6))
    
    for i in range(10):
        plt.subplot(2,5,i+1)
        plt.xticks([])
        plt.yticks([])
        plt.xlabel("Class {0}".format(i+1))
        info, clip, hasContour, contour, fish_id, frames = loadVideo(movs[samp_vids[i]])
        plt.imshow(clip[samp_fram[i]])
        cline = contour[samp_fram[i]]
        thisContour = getContour(cline, return_what="Normalized")
        plt.scatter(thisContour[:,0],thisContour[:,1],s=1)
    plt.show()
        
printClassExamples()

# %%
bins = np.append(np.arange(0,101000,100),300000)
plt.figure(figsize=(10,3))
plt.bar(np.arange(1010),np.histogram(movs_length, bins)[0],1)
ax = plt.gca()
ax.set_xticklabels([0,0,20000,40000,60000,80000,">100000"])
ax.set_yscale("log")
# ax.set_xlabel("Number of Frames/Detection")
# ax.set_ylabel("Nu")
plt.show()

# %%
sums = np.sum(movs_length)
sums30k = np.sum(movs_length[movs_length>=5000])
print(sums30k*1.0/sums)
print(np.sum(movs_length>=30000))
# Out:
# 0.427325810465
# 398

# %%
def loadGT(video_id, length):
    path = "/afs/inf.ed.ac.uk/user/s14/s1413557/f4k-2017-msc-master/matt-msc/workspace/gt/"+video_id+".f4kgt"
    with open(path) as f:
        line = f.readlines()
        line = line[0][1:-1]
        tags = line.split(",")
        gts = [None] * length
        for t in tags:
            try:
                left, right = t.split(":",1)
                gts[int(left.strip()[1:-1])-1] = int(right.strip())
            except Exception:
                print(t)
    return np.array(gts)

tr = np.arange(30598,30695)
picker = tr[7]
movid = movs[picker]
info, clip, hasContour, contour, fish_id, frames = loadVideo(movid)
print(movid)

gts = loadGT(movid[0], frames)
#print(gts.tolist())
gts[gts == None] = -1
gts += 1

fish = gts[gts>=6]
fish = fish[fish<=8]

print("")
print("{0} out of {1} is recognized as a fish".format(len(fish),len(gts)))
counts = np.histogram(gts,np.arange(0,12))[0]
#print(counts)
print("None: {0}".format(counts[0]))
for i in np.arange(1,11):
    print("Class {0}: {1}".format(i,counts[i]))
#print(np.arange(len(gts))[gts==0])
print("")

h = 1580
print(gts[h:h+5])
plotStuff(info, clip, hasContour, contour, movid, limit_lower=h, limit_upper=h+5, width=5, classify=True)
h+=5
print(gts[h:h+5])
plotStuff(info, clip, hasContour, contour, movid, limit_lower=h, limit_upper=h+5, width=5, classify=True)
h+=5
print(gts[h:h+5])
plotStuff(info, clip, hasContour, contour, movid, limit_lower=h, limit_upper=h+5, width=5, classify=True)
# Out:
# ['13b0bd6d7c9fc8e096f04bf408e850e9#201104170900' '37' '0']
#
# 1360 out of 3205 is recognized as a fish
# None: 198
# Class 1: 23
# Class 2: 0
# Class 3: 1280
# Class 4: 13
# Class 5: 30
# Class 6: 66
# Class 7: 338
# Class 8: 956
# Class 9: 301
# Class 10: 0
#
# [3 9 3 3 9]
# [3 3 9 8 3]
# [8 8 3 8 3]

# %% [markdown]
# # PCA
# ---

# %%
featureNames()[1000:]
# Out:
# ['Co-occurance Matrix (57,1)',
#  'Co-occurance Matrix (58,1)',
#  'Co-occurance Matrix (59,1)',
#  'Co-occurance Matrix (60,1)',
#  'Co-occurance Matrix (61,1)',
#  'Co-occurance Matrix (62,1)',
#  'Co-occurance Matrix (63,1)',
#  'Co-occurance Matrix (64,1)',
#  'Co-occurance Matrix (65,1)',
#  'Co-occurance Matrix (66,1)',
#  'Co-occurance Matrix (67,1)',
#  'Co-occurance Matrix (68,1)',
#  'Co-occurance Matrix (69,1)',
#  'Co-occurance Matrix (70,1)',
#  'Co-occurance Matrix (71,1)',
#  'Co-occurance Matrix (72,1)',
#  'Co-occurance Matrix (1,2)',
#  'Co-occurance Matrix (2,2)',
#  'Co-occurance Matrix (3,2)',
#  'Co-occurance Matrix (4,2)',
#  'Co-occurance Matrix (5,2)',
#  'Co-occurance Matrix (6,2)',
#  'Co-occurance Matrix (7,2)',
#  'Co-occurance Matrix (8,2)',
#  'Co-occurance Matrix (9,2)',
#  'Co-occurance Matrix (10,2)',
#  'Co-occurance Matrix (11,2)',
#  'Co-occurance Matrix (12,2)',
#  'Co-occurance Matrix (13,2)',
#  'Co-occurance Matrix (14,2)',
#  'Co-occurance Matrix (15,2)',
#  'Co-occurance Matrix (16,2)',
#  'Co-occurance Matrix (17,2)',
#  'Co-occurance Matrix (18,2)',
#  'Co-occurance Matrix (19,2)',
#  'Co-occurance Matrix (20,2)',
#  'Co-occurance Matrix (21,2)',
#  'Co-occurance Matrix (22,2)',
#  'Co-occurance Matrix (23,2)',
#  'Co-occurance Matrix (24,2)',
#  'Co-occurance Matrix (25,2)',
#  'Co-occurance Matrix (26,2)',
#  'Co-occurance Matrix (27,2)',
#  'Co-occurance Matrix (28,2)',
#  'Co-occurance Matrix (29,2)',
#  'Co-occurance Matrix (30,2)',
#  'Co-occurance Matrix (31,2)',
#  'Co-occurance Matrix (32,2)',
#  'Co-occurance Matrix (33,2)',
#  'Co-occurance Matrix (34,2)',
#  'Co-occurance Matrix (35,2)',
#  'Co-occurance Matrix (36,2)',
#  'Co-occurance Matrix (37,2)',
#  'Co-occurance Matrix (38,2)',
#  'Co-occurance Matrix (39,2)',
#  'Co-occurance Matrix (40,2)',
#  'Co-occurance Matrix (41,2)',
#  'Co-occurance Matrix (42,2)',
#  'Co-occurance Matrix (43,2)',
#  'Co-occurance Matrix (44,2)',
#  'Co-occurance Matrix (45,2)',
#  'Co-occurance Matrix (46,2)',
#  'Co-occurance Matrix (47,2)',
#  'Co-occurance Matrix (48,2)',
#  'Co-occurance Matrix (49,2)',
#  'Co-occurance Matrix (50,2)',
#  'Co-occurance Matrix (51,2)',
#  'Co-occurance Matrix (52,2)',
#  'Co-occurance Matrix (53,2)',
#  'Co-occurance Matrix (54,2)',
#  'Co-occurance Matrix (55,2)',
#  'Co-occurance Matrix (56,2)',
#  'Co-occurance Matrix (57,2)',
#  'Co-occurance Matrix (58,2)',
#  'Co-occurance Matrix (59,2)',
#  'Co-occurance Matrix (60,2)',
#  'Co-occurance Matrix (61,2)',
#  'Co-occurance Matrix (62,2)',
#  'Co-occurance Matrix (63,2)',
#  'Co-occurance Matrix (64,2)',
#  'Co-occurance Matrix (65,2)',
#  'Co-occurance Matrix (66,2)',
#  'Co-occurance Matrix (67,2)',
#  'Co-occurance Matrix (68,2)',
#  'Co-occurance Matrix (69,2)',
#  'Co-occurance Matrix (70,2)',
#  'Co-occurance Matrix (71,2)',
#  'Co-occurance Matrix (72,2)',
#  'Co-occurance Matrix (1,3)',
#  'Co-occurance Matrix (2,3)',
#  'Co-occurance Matrix (3,3)',
#  'Co-occurance Matrix (4,3)',
#  'Co-occurance Matrix (5,3)',
#  'Co-occurance Matrix (6,3)',
#  'Co-occurance Matrix (7,3)',
#  'Co-occurance Matrix (8,3)',
#  'Co-occurance Matrix (9,3)',
#  'Co-occurance Matrix (10,3)',
#  'Co-occurance Matrix (11,3)',
#  'Co-occurance Matrix (12,3)',
#  'Co-occurance Matrix (13,3)',
#  'Co-occurance Matrix (14,3)',
#  'Co-occurance Matrix (15,3)',
#  'Co-occurance Matrix (16,3)',
#  'Co-occurance Matrix (17,3)',
#  'Co-occurance Matrix (18,3)',
#  'Co-occurance Matrix (19,3)',
#  'Co-occurance Matrix (20,3)',
#  'Co-occurance Matrix (21,3)',
#  'Co-occurance Matrix (22,3)',
#  'Co-occurance Matrix (23,3)',
#  'Co-occurance Matrix (24,3)',
#  'Co-occurance Matrix (25,3)',
#  'Co-occurance Matrix (26,3)',
#  'Co-occurance Matrix (27,3)',
#  'Co-occurance Matrix (28,3)',
#  'Co-occurance Matrix (29,3)',
#  'Co-occurance Matrix (30,3)',
#  'Co-occurance Matrix (31,3)',
#  'Co-occurance Matrix (32,3)',
#  'Co-occurance Matrix (33,3)',
#  'Co-occurance Matrix (34,3)',
#  'Co-occurance Matrix (35,3)',
#  'Co-occurance Matrix (36,3)',
#  'Co-occurance Matrix (37,3)',
#  'Co-occurance Matrix (38,3)',
#  'Co-occurance Matrix (39,3)',
#  'Co-occurance Matrix (40,3)',
#  'Co-occurance Matrix (41,3)',
#  'Co-occurance Matrix (42,3)',
#  'Co-occurance Matrix (43,3)',
#  'Co-occurance Matrix (44,3)',
#  'Co-occurance Matrix (45,3)',
#  'Co-occurance Matrix (46,3)',
#  'Co-occurance Matrix (47,3)',
#  'Co-occurance Matrix (48,3)',
#  'Co-occurance Matrix (49,3)',
#  'Co-occurance Matrix (50,3)',
#  'Co-occurance Matrix (51,3)',
#  'Co-occurance Matrix (52,3)',
#  'Co-occurance Matrix (53,3)',
#  'Co-occurance Matrix (54,3)',
#  'Co-occurance Matrix (55,3)',
#  'Co-occurance Matrix (56,3)',
#  'Co-occurance Matrix (57,3)',
#  'Co-occurance Matrix (58,3)',
#  'Co-occurance Matrix (59,3)',
#  'Co-occurance Matrix (60,3)',
#  'Co-occurance Matrix (61,3)',
#  'Co-occurance Matrix (62,3)',
#  'Co-occurance Matrix (63,3)',
#  'Co-occurance Matrix (64,3)',
#  'Co-occurance Matrix (65,3)',
#  'Co-occurance Matrix (66,3)',
#  'Co-occurance Matrix (67,3)',
#  'Co-occurance Matrix (68,3)',
#  'Co-occurance Matrix (69,3)',
#  'Co-occurance Matrix (70,3)',
#  'Co-occurance Matrix (71,3)',
#  'Co-occurance Matrix (72,3)',
#  'Co-occurance Matrix (1,4)',
#  'Co-occurance Matrix (2,4)',
#  'Co-occurance Matrix (3,4)',
#  'Co-occurance Matrix (4,4)',
#  'Co-occurance Matrix (5,4)',
#  'Co-occurance Matrix (6,4)',
#  'Co-occurance Matrix (7,4)',
#  'Co-occurance Matrix (8,4)',
#  'Co-occurance Matrix (9,4)',
#  'Co-occurance Matrix (10,4)',
#  'Co-occurance Matrix (11,4)',
#  'Co-occurance Matrix (12,4)',
#  'Co-occurance Matrix (13,4)',
#  'Co-occurance Matrix (14,4)',
#  'Co-occurance Matrix (15,4)',
#  'Co-occurance Matrix (16,4)',
#  'Co-occurance Matrix (17,4)',
#  'Co-occurance Matrix (18,4)',
#  'Co-occurance Matrix (19,4)',
#  'Co-occurance Matrix (20,4)',
#  'Co-occurance Matrix (21,4)',
#  'Co-occurance Matrix (22,4)',
#  'Co-occurance Matrix (23,4)',
#  'Co-occurance Matrix (24,4)',
#  'Co-occurance Matrix (25,4)',
#  'Co-occurance Matrix (26,4)',
#  'Co-occurance Matrix (27,4)',
#  'Co-occurance Matrix (28,4)',
#  'Co-occurance Matrix (29,4)',
#  'Co-occurance Matrix (30,4)',
#  'Co-occurance Matrix (31,4)',
#  'Co-occurance Matrix (32,4)',
#  'Co-occurance Matrix (33,4)',
#  'Co-occurance Matrix (34,4)',
#  'Co-occurance Matrix (35,4)',
#  'Co-occurance Matrix (36,4)',
#  'Co-occurance Matrix (37,4)',
#  'Co-occurance Matrix (38,4)',
#  'Co-occurance Matrix (39,4)',
#  'Co-occurance Matrix (40,4)',
#  'Co-occurance Matrix (41,4)',
#  'Co-occurance Matrix (42,4)',
#  'Co-occurance Matrix (43,4)',
#  'Co-occurance Matrix (44,4)',
#  'Co-occurance Matrix (45,4)',
#  'Co-occurance Matrix (46,4)',
#  'Co-occurance Matrix (47,4)',
#  'Co-occurance Matrix (48,4)',
#  'Co-occurance Matrix (49,4)',
#  'Co-occurance Matrix (50,4)',
#  'Co-occurance Matrix (51,4)',
#  'Co-occurance Matrix (52,4)',
#  'Co-occurance Matrix (53,4)',
#  'Co-occurance Matrix (54,4)',
#  'Co-occurance Matrix (55,4)',
#  'Co-occurance Matrix (56,4)',
#  'Co-occurance Matrix (57,4)',
#  'Co-occurance Matrix (58,4)',
#  'Co-occurance Matrix (59,4)',
#  'Co-occurance Matrix (60,4)',
#  'Co-occurance Matrix (61,4)',
#  'Co-occurance Matrix (62,4)',
#  'Co-occurance Matrix (63,4)',
#  'Co-occurance Matrix (64,4)',
#  'Co-occurance Matrix (65,4)',
#  'Co-occurance Matrix (66,4)',
#  'Co-occurance Matrix (67,4)',
#  'Co-occurance Matrix (68,4)',
#  'Co-occurance Matrix (69,4)',
#  'Co-occurance Matrix (70,4)',
#  'Co-occurance Matrix (71,4)',
#  'Co-occurance Matrix (72,4)',
#  'Co-occurance Matrix (1,5)',
#  'Co-occurance Matrix (2,5)',
#  'Co-occurance Matrix (3,5)',
#  'Co-occurance Matrix (4,5)',
#  'Co-occurance Matrix (5,5)',
#  'Co-occurance Matrix (6,5)',
#  'Co-occurance Matrix (7,5)',
#  'Co-occurance Matrix (8,5)',
#  'Co-occurance Matrix (9,5)',
#  'Co-occurance Matrix (10,5)',
#  'Co-occurance Matrix (11,5)',
#  'Co-occurance Matrix (12,5)',
#  'Co-occurance Matrix (13,5)',
#  'Co-occurance Matrix (14,5)',
#  'Co-occurance Matrix (15,5)',
#  'Co-occurance Matrix (16,5)',
#  'Co-occurance Matrix (17,5)',
#  'Co-occurance Matrix (18,5)',
#  'Co-occurance Matrix (19,5)',
#  'Co-occurance Matrix (20,5)',
#  'Co-occurance Matrix (21,5)',
#  'Co-occurance Matrix (22,5)',
#  'Co-occurance Matrix (23,5)',
#  'Co-occurance Matrix (24,5)',
#  'Co-occurance Matrix (25,5)',
#  'Co-occurance Matrix (26,5)',
#  'Co-occurance Matrix (27,5)',
#  'Co-occurance Matrix (28,5)',
#  'Co-occurance Matrix (29,5)',
#  'Co-occurance Matrix (30,5)',
#  'Co-occurance Matrix (31,5)',
#  'Co-occurance Matrix (32,5)',
#  'Co-occurance Matrix (33,5)',
#  'Co-occurance Matrix (34,5)',
#  'Co-occurance Matrix (35,5)',
#  'Co-occurance Matrix (36,5)',
#  'Co-occurance Matrix (37,5)',
#  'Co-occurance Matrix (38,5)',
#  'Co-occurance Matrix (39,5)',
#  'Co-occurance Matrix (40,5)',
#  'Co-occurance Matrix (41,5)',
#  'Co-occurance Matrix (42,5)',
#  'Co-occurance Matrix (43,5)',
#  'Co-occurance Matrix (44,5)',
#  'Co-occurance Matrix (45,5)',
#  'Co-occurance Matrix (46,5)',
#  'Co-occurance Matrix (47,5)',
#  'Co-occurance Matrix (48,5)',
#  'Co-occurance Matrix (49,5)',
#  'Co-occurance Matrix (50,5)',
#  'Co-occurance Matrix (51,5)',
#  'Co-occurance Matrix (52,5)',
#  'Co-occurance Matrix (53,5)',
#  'Co-occurance Matrix (54,5)',
#  'Co-occurance Matrix (55,5)',
#  'Co-occurance Matrix (56,5)',
#  'Co-occurance Matrix (57,5)',
#  'Co-occurance Matrix (58,5)',
#  'Co-occurance Matrix (59,5)',
#  'Co-occurance Matrix (60,5)',
#  'Co-occurance Matrix (61,5)',
#  'Co-occurance Matrix (62,5)',
#  'Co-occurance Matrix (63,5)',
#  'Co-occurance Matrix (64,5)',
#  'Co-occurance Matrix (65,5)',
#  'Co-occurance Matrix (66,5)',
#  'Co-occurance Matrix (67,5)',
#  'Co-occurance Matrix (68,5)',
#  'Co-occurance Matrix (69,5)',
#  'Co-occurance Matrix (70,5)',
#  'Co-occurance Matrix (71,5)',
#  'Co-occurance Matrix (72,5)',
#  'Co-occurance Matrix (1,6)',
#  'Co-occurance Matrix (2,6)',
#  'Co-occurance Matrix (3,6)',
#  'Co-occurance Matrix (4,6)',
#  'Co-occurance Matrix (5,6)',
#  'Co-occurance Matrix (6,6)',
#  'Co-occurance Matrix (7,6)',
#  'Co-occurance Matrix (8,6)',
#  'Co-occurance Matrix (9,6)',
#  'Co-occurance Matrix (10,6)',
#  'Co-occurance Matrix (11,6)',
#  'Co-occurance Matrix (12,6)',
#  'Co-occurance Matrix (13,6)',
#  'Co-occurance Matrix (14,6)',
#  'Co-occurance Matrix (15,6)',
#  'Co-occurance Matrix (16,6)',
#  'Co-occurance Matrix (17,6)',
#  'Co-occurance Matrix (18,6)',
#  'Co-occurance Matrix (19,6)',
#  'Co-occurance Matrix (20,6)',
#  'Co-occurance Matrix (21,6)',
#  'Co-occurance Matrix (22,6)',
#  'Co-occurance Matrix (23,6)',
#  'Co-occurance Matrix (24,6)',
#  'Co-occurance Matrix (25,6)',
#  'Co-occurance Matrix (26,6)',
#  'Co-occurance Matrix (27,6)',
#  'Co-occurance Matrix (28,6)',
#  'Co-occurance Matrix (29,6)',
#  'Co-occurance Matrix (30,6)',
#  'Co-occurance Matrix (31,6)',
#  'Co-occurance Matrix (32,6)',
#  'Co-occurance Matrix (33,6)',
#  'Co-occurance Matrix (34,6)',
#  'Co-occurance Matrix (35,6)',
#  'Co-occurance Matrix (36,6)',
#  'Co-occurance Matrix (37,6)',
#  'Co-occurance Matrix (38,6)',
#  'Co-occurance Matrix (39,6)',
#  'Co-occurance Matrix (40,6)',
#  'Co-occurance Matrix (41,6)',
#  'Co-occurance Matrix (42,6)',
#  'Co-occurance Matrix (43,6)',
#  'Co-occurance Matrix (44,6)',
#  'Co-occurance Matrix (45,6)',
#  'Co-occurance Matrix (46,6)',
#  'Co-occurance Matrix (47,6)',
#  'Co-occurance Matrix (48,6)',
#  'Co-occurance Matrix (49,6)',
#  'Co-occurance Matrix (50,6)',
#  'Co-occurance Matrix (51,6)',
#  'Co-occurance Matrix (52,6)',
#  'Co-occurance Matrix (53,6)',
#  'Co-occurance Matrix (54,6)',
#  'Co-occurance Matrix (55,6)',
#  'Co-occurance Matrix (56,6)',
#  'Co-occurance Matrix (57,6)',
#  'Co-occurance Matrix (58,6)',
#  'Co-occurance Matrix (59,6)',
#  'Co-occurance Matrix (60,6)',
#  'Co-occurance Matrix (61,6)',
#  'Co-occurance Matrix (62,6)',
#  'Co-occurance Matrix (63,6)',
#  'Co-occurance Matrix (64,6)',
#  'Co-occurance Matrix (65,6)',
#  'Co-occurance Matrix (66,6)',
#  'Co-occurance Matrix (67,6)',
#  'Co-occurance Matrix (68,6)',
#  'Co-occurance Matrix (69,6)',
#  'Co-occurance Matrix (70,6)',
#  'Co-occurance Matrix (71,6)',
#  'Co-occurance Matrix (72,6)',
#  'Co-occurance Matrix (1,7)',
#  'Co-occurance Matrix (2,7)',
#  'Co-occurance Matrix (3,7)',
#  'Co-occurance Matrix (4,7)',
#  'Co-occurance Matrix (5,7)',
#  'Co-occurance Matrix (6,7)',
#  'Co-occurance Matrix (7,7)',
#  'Co-occurance Matrix (8,7)',
#  'Co-occurance Matrix (9,7)',
#  'Co-occurance Matrix (10,7)',
#  'Co-occurance Matrix (11,7)',
#  'Co-occurance Matrix (12,7)',
#  'Co-occurance Matrix (13,7)',
#  'Co-occurance Matrix (14,7)',
#  'Co-occurance Matrix (15,7)',
#  'Co-occurance Matrix (16,7)',
#  'Co-occurance Matrix (17,7)',
#  'Co-occurance Matrix (18,7)',
#  'Co-occurance Matrix (19,7)',
#  'Co-occurance Matrix (20,7)',
#  'Co-occurance Matrix (21,7)',
#  'Co-occurance Matrix (22,7)',
#  'Co-occurance Matrix (23,7)',
#  'Co-occurance Matrix (24,7)',
#  'Co-occurance Matrix (25,7)',
#  'Co-occurance Matrix (26,7)',
#  'Co-occurance Matrix (27,7)',
#  'Co-occurance Matrix (28,7)',
#  'Co-occurance Matrix (29,7)',
#  'Co-occurance Matrix (30,7)',
#  'Co-occurance Matrix (31,7)',
#  'Co-occurance Matrix (32,7)',
#  'Co-occurance Matrix (33,7)',
#  'Co-occurance Matrix (34,7)',
#  'Co-occurance Matrix (35,7)',
#  'Co-occurance Matrix (36,7)',
#  'Co-occurance Matrix (37,7)',
#  'Co-occurance Matrix (38,7)',
#  'Co-occurance Matrix (39,7)',
#  'Co-occurance Matrix (40,7)',
#  'Co-occurance Matrix (41,7)',
#  'Co-occurance Matrix (42,7)',
#  'Co-occurance Matrix (43,7)',
#  'Co-occurance Matrix (44,7)',
#  'Co-occurance Matrix (45,7)',
#  'Co-occurance Matrix (46,7)',
#  'Co-occurance Matrix (47,7)',
#  'Co-occurance Matrix (48,7)',
#  'Co-occurance Matrix (49,7)',
#  'Co-occurance Matrix (50,7)',
#  'Co-occurance Matrix (51,7)',
#  'Co-occurance Matrix (52,7)',
#  'Co-occurance Matrix (53,7)',
#  'Co-occurance Matrix (54,7)',
#  'Co-occurance Matrix (55,7)',
#  'Co-occurance Matrix (56,7)',
#  'Co-occurance Matrix (57,7)',
#  'Co-occurance Matrix (58,7)',
#  'Co-occurance Matrix (59,7)',
#  'Co-occurance Matrix (60,7)',
#  'Co-occurance Matrix (61,7)',
#  'Co-occurance Matrix (62,7)',
#  'Co-occurance Matrix (63,7)',
#  'Co-occurance Matrix (64,7)',
#  'Co-occurance Matrix (65,7)',
#  'Co-occurance Matrix (66,7)',
#  'Co-occurance Matrix (67,7)',
#  'Co-occurance Matrix (68,7)',
#  'Co-occurance Matrix (69,7)',
#  'Co-occurance Matrix (70,7)',
#  'Co-occurance Matrix (71,7)',
#  'Co-occurance Matrix (72,7)',
#  'Co-occurance Matrix (1,8)',
#  'Co-occurance Matrix (2,8)',
#  'Co-occurance Matrix (3,8)',
#  'Co-occurance Matrix (4,8)',
#  'Co-occurance Matrix (5,8)',
#  'Co-occurance Matrix (6,8)',
#  'Co-occurance Matrix (7,8)',
#  'Co-occurance Matrix (8,8)',
#  'Co-occurance Matrix (9,8)',
#  'Co-occurance Matrix (10,8)',
#  'Co-occurance Matrix (11,8)',
#  'Co-occurance Matrix (12,8)',
#  'Co-occurance Matrix (13,8)',
#  'Co-occurance Matrix (14,8)',
#  'Co-occurance Matrix (15,8)',
#  'Co-occurance Matrix (16,8)',
#  'Co-occurance Matrix (17,8)',
#  'Co-occurance Matrix (18,8)',
#  'Co-occurance Matrix (19,8)',
#  'Co-occurance Matrix (20,8)',
#  'Co-occurance Matrix (21,8)',
#  'Co-occurance Matrix (22,8)',
#  'Co-occurance Matrix (23,8)',
#  'Co-occurance Matrix (24,8)',
#  'Co-occurance Matrix (25,8)',
#  'Co-occurance Matrix (26,8)',
#  'Co-occurance Matrix (27,8)',
#  'Co-occurance Matrix (28,8)',
#  'Co-occurance Matrix (29,8)',
#  'Co-occurance Matrix (30,8)',
#  'Co-occurance Matrix (31,8)',
#  'Co-occurance Matrix (32,8)',
#  'Co-occurance Matrix (33,8)',
#  'Co-occurance Matrix (34,8)',
#  'Co-occurance Matrix (35,8)',
#  'Co-occurance Matrix (36,8)',
#  'Co-occurance Matrix (37,8)',
#  'Co-occurance Matrix (38,8)',
#  'Co-occurance Matrix (39,8)',
#  'Co-occurance Matrix (40,8)',
#  'Co-occurance Matrix (41,8)',
#  'Co-occurance Matrix (42,8)',
#  'Co-occurance Matrix (43,8)',
#  'Co-occurance Matrix (44,8)',
#  'Co-occurance Matrix (45,8)',
#  'Co-occurance Matrix (46,8)',
#  'Co-occurance Matrix (47,8)',
#  'Co-occurance Matrix (48,8)',
#  'Co-occurance Matrix (49,8)',
#  'Co-occurance Matrix (50,8)',
#  'Co-occurance Matrix (51,8)',
#  'Co-occurance Matrix (52,8)',
#  'Co-occurance Matrix (53,8)',
#  'Co-occurance Matrix (54,8)',
#  'Co-occurance Matrix (55,8)',
#  'Co-occurance Matrix (56,8)',
#  'Co-occurance Matrix (57,8)',
#  'Co-occurance Matrix (58,8)',
#  'Co-occurance Matrix (59,8)',
#  'Co-occurance Matrix (60,8)',
#  'Co-occurance Matrix (61,8)',
#  'Co-occurance Matrix (62,8)',
#  'Co-occurance Matrix (63,8)',
#  'Co-occurance Matrix (64,8)',
#  'Co-occurance Matrix (65,8)',
#  'Co-occurance Matrix (66,8)',
#  'Co-occurance Matrix (67,8)',
#  'Co-occurance Matrix (68,8)',
#  'Co-occurance Matrix (69,8)',
#  'Co-occurance Matrix (70,8)',
#  'Co-occurance Matrix (71,8)',
#  'Co-occurance Matrix (72,8)',
#  'Co-occurance Matrix (1,9)',
#  'Co-occurance Matrix (2,9)',
#  'Co-occurance Matrix (3,9)',
#  'Co-occurance Matrix (4,9)',
#  'Co-occurance Matrix (5,9)',
#  'Co-occurance Matrix (6,9)',
#  'Co-occurance Matrix (7,9)',
#  'Co-occurance Matrix (8,9)',
#  'Co-occurance Matrix (9,9)',
#  'Co-occurance Matrix (10,9)',
#  'Co-occurance Matrix (11,9)',
#  'Co-occurance Matrix (12,9)',
#  'Co-occurance Matrix (13,9)',
#  'Co-occurance Matrix (14,9)',
#  'Co-occurance Matrix (15,9)',
#  'Co-occurance Matrix (16,9)',
#  'Co-occurance Matrix (17,9)',
#  'Co-occurance Matrix (18,9)',
#  'Co-occurance Matrix (19,9)',
#  'Co-occurance Matrix (20,9)',
#  'Co-occurance Matrix (21,9)',
#  'Co-occurance Matrix (22,9)',
#  'Co-occurance Matrix (23,9)',
#  'Co-occurance Matrix (24,9)',
#  'Co-occurance Matrix (25,9)',
#  'Co-occurance Matrix (26,9)',
#  'Co-occurance Matrix (27,9)',
#  'Co-occurance Matrix (28,9)',
#  'Co-occurance Matrix (29,9)',
#  'Co-occurance Matrix (30,9)',
#  'Co-occurance Matrix (31,9)',
#  'Co-occurance Matrix (32,9)',
#  'Co-occurance Matrix (33,9)',
#  'Co-occurance Matrix (34,9)',
#  'Co-occurance Matrix (35,9)',
#  'Co-occurance Matrix (36,9)',
#  'Co-occurance Matrix (37,9)',
#  'Co-occurance Matrix (38,9)',
#  'Co-occurance Matrix (39,9)',
#  'Co-occurance Matrix (40,9)',
#  'Co-occurance Matrix (41,9)',
#  'Co-occurance Matrix (42,9)',
#  'Co-occurance Matrix (43,9)',
#  'Co-occurance Matrix (44,9)',
#  'Co-occurance Matrix (45,9)',
#  'Co-occurance Matrix (46,9)',
#  'Co-occurance Matrix (47,9)',
#  'Co-occurance Matrix (48,9)',
#  'Co-occurance Matrix (49,9)',
#  'Co-occurance Matrix (50,9)',
#  'Co-occurance Matrix (51,9)',
#  'Co-occurance Matrix (52,9)',
#  'Co-occurance Matrix (53,9)',
#  'Co-occurance Matrix (54,9)',
#  'Co-occurance Matrix (55,9)',
#  'Co-occurance Matrix (56,9)',
#  'Co-occurance Matrix (57,9)',
#  'Co-occurance Matrix (58,9)',
#  'Co-occurance Matrix (59,9)',
#  'Co-occurance Matrix (60,9)',
#  'Co-occurance Matrix (61,9)',
#  'Co-occurance Matrix (62,9)',
#  'Co-occurance Matrix (63,9)',
#  'Co-occurance Matrix (64,9)',
#  'Co-occurance Matrix (65,9)',
#  'Co-occurance Matrix (66,9)',
#  'Co-occurance Matrix (67,9)',
#  'Co-occurance Matrix (68,9)',
#  'Co-occurance Matrix (69,9)',
#  'Co-occurance Matrix (70,9)',
#  'Co-occurance Matrix (71,9)',
#  'Co-occurance Matrix (72,9)',
#  'Co-occurance Matrix (1,10)',
#  'Co-occurance Matrix (2,10)',
#  'Co-occurance Matrix (3,10)',
#  'Co-occurance Matrix (4,10)',
#  'Co-occurance Matrix (5,10)',
#  'Co-occurance Matrix (6,10)',
#  'Co-occurance Matrix (7,10)',
#  'Co-occurance Matrix (8,10)',
#  'Co-occurance Matrix (9,10)',
#  'Co-occurance Matrix (10,10)',
#  'Co-occurance Matrix (11,10)',
#  'Co-occurance Matrix (12,10)',
#  'Co-occurance Matrix (13,10)',
#  'Co-occurance Matrix (14,10)',
#  'Co-occurance Matrix (15,10)',
#  'Co-occurance Matrix (16,10)',
#  'Co-occurance Matrix (17,10)',
#  'Co-occurance Matrix (18,10)',
#  'Co-occurance Matrix (19,10)',
#  'Co-occurance Matrix (20,10)',
#  'Co-occurance Matrix (21,10)',
#  'Co-occurance Matrix (22,10)',
#  'Co-occurance Matrix (23,10)',
#  'Co-occurance Matrix (24,10)',
#  'Co-occurance Matrix (25,10)',
#  'Co-occurance Matrix (26,10)',
#  'Co-occurance Matrix (27,10)',
#  'Co-occurance Matrix (28,10)',
#  'Co-occurance Matrix (29,10)',
#  'Co-occurance Matrix (30,10)',
#  'Co-occurance Matrix (31,10)',
#  'Co-occurance Matrix (32,10)',
#  'Co-occurance Matrix (33,10)',
#  'Co-occurance Matrix (34,10)',
#  'Co-occurance Matrix (35,10)',
#  'Co-occurance Matrix (36,10)',
#  'Co-occurance Matrix (37,10)',
#  'Co-occurance Matrix (38,10)',
#  'Co-occurance Matrix (39,10)',
#  'Co-occurance Matrix (40,10)',
#  'Co-occurance Matrix (41,10)',
#  'Co-occurance Matrix (42,10)',
#  'Co-occurance Matrix (43,10)',
#  'Co-occurance Matrix (44,10)',
#  'Co-occurance Matrix (45,10)',
#  'Co-occurance Matrix (46,10)',
#  'Co-occurance Matrix (47,10)',
#  'Co-occurance Matrix (48,10)',
#  'Co-occurance Matrix (49,10)',
#  'Co-occurance Matrix (50,10)',
#  'Co-occurance Matrix (51,10)',
#  'Co-occurance Matrix (52,10)',
#  'Co-occurance Matrix (53,10)',
#  'Co-occurance Matrix (54,10)',
#  'Co-occurance Matrix (55,10)',
#  'Co-occurance Matrix (56,10)',
#  'Co-occurance Matrix (57,10)',
#  'Co-occurance Matrix (58,10)',
#  'Co-occurance Matrix (59,10)',
#  'Co-occurance Matrix (60,10)',
#  'Co-occurance Matrix (61,10)',
#  'Co-occurance Matrix (62,10)',
#  'Co-occurance Matrix (63,10)',
#  'Co-occurance Matrix (64,10)',
#  'Co-occurance Matrix (65,10)',
#  'Co-occurance Matrix (66,10)',
#  'Co-occurance Matrix (67,10)',
#  'Co-occurance Matrix (68,10)',
#  'Co-occurance Matrix (69,10)',
#  'Co-occurance Matrix (70,10)',
#  'Co-occurance Matrix (71,10)',
#  'Co-occurance Matrix (72,10)',
#  'Moment Invariant 1',
#  'Moment Invariant 2',
#  'Moment Invariant 3',
#  'Moment Invariant 4',
#  'Moment Invariant 5',
#  'Moment Invariant 6',
#  'Moment Invariant 7',
#  'Moment Invariant 8',
#  'Moment Invariant 9',
#  'Moment Invariant 10',
#  'Moment Invariant 11',
#  'Moment Invariant 12',
#  'Moment Invariant 13',
#  'Moment Invariant 14',
#  'Moment Invariant 15',
#  'Moment Invariant 16',
#  'Moment Invariant 17',
#  'Moment Invariant 18',
#  'Moment Invariant 19',
#  'Moment Invariant 20',
#  'Moment Invariant 21',
#  'Moment Invariant 22',
#  'Moment Invariant 23',
#  'Moment Invariant 24',
#  'Moment Invariant 25',
#  'Moment Invariant 26',
#  'Moment Invariant 27',
#  'Moment Invariant 28',
#  'Moment Invariant 29',
#  'Moment Invariant 30',
#  'Moment Invariant 31',
#  'Moment Invariant 32',
#  'Moment Invariant 33',
#  'Moment Invariant 34',
#  'Moment Invariant 35',
#  'Moment Invariant 36',
#  'Moment Invariant 37',
#  'Moment Invariant 38',
#  'Moment Invariant 39',
#  'Moment Invariant 40',
#  'Moment Invariant 41',
#  'Moment Invariant 42',
#  'PHOG 1',
#  'PHOG 2',
#  'PHOG 3',
#  'PHOG 4',
#  'PHOG 5',
#  'PHOG 6',
#  'PHOG 7',
#  'PHOG 8',
#  'PHOG 9',
#  'PHOG 10',
#  'PHOG 11',
#  'PHOG 12',
#  'PHOG 13',
#  'PHOG 14',
#  'PHOG 15',
#  'PHOG 16',
#  'PHOG 17',
#  'PHOG 18',
#  'PHOG 19',
#  'PHOG 20',
#  'PHOG 21',
#  'PHOG 22',
#  'PHOG 23',
#  'PHOG 24',
#  'PHOG 25',
#  'PHOG 26',
#  'PHOG 27',
#  'PHOG 28',
#  'PHOG 29',
#  'PHOG 30',
#  'PHOG 31',
#  'PHOG 32',
#  'PHOG 33',
#  'PHOG 34',
#  'PHOG 35',
#  'PHOG 36',
#  'PHOG 37',
#  'PHOG 38',
#  'PHOG 39',
#  'PHOG 40',
#  'PHOG 41',
#  'PHOG 42',
#  'PHOG 43',
#  'PHOG 44',
#  'PHOG 45',
#  'PHOG 46',
#  'PHOG 47',
#  'PHOG 48',
#  'PHOG 49',
#  'PHOG 50',
#  'PHOG 51',
#  'PHOG 52',
#  'PHOG 53',
#  'PHOG 54',
#  'PHOG 55',
#  'PHOG 56',
#  'PHOG 57',
#  'PHOG 58',
#  'PHOG 59',
#  'PHOG 60',
#  'PHOG 61',
#  'PHOG 62',
#  'PHOG 63',
#  'PHOG 64',
#  'PHOG 65',
#  'PHOG 66',
#  'PHOG 67',
#  'PHOG 68',
#  'PHOG 69',
#  'PHOG 70',
#  'PHOG 71',
#  'PHOG 72',
#  'PHOG 73',
#  'PHOG 74',
#  'PHOG 75',
#  'PHOG 76',
#  'PHOG 77',
#  'PHOG 78',
#  'PHOG 79',
#  'PHOG 80',
#  'PHOG 81',
#  'PHOG 82',
#  'PHOG 83',
#  'PHOG 84',
#  'PHOG 85',
#  'PHOG 86',
#  'PHOG 87',
#  'PHOG 88',
#  'PHOG 89',
#  'PHOG 90',
#  'PHOG 91',
#  'PHOG 92',
#  'PHOG 93',
#  'PHOG 94',
#  'PHOG 95',
#  'PHOG 96',
#  'PHOG 97',
#  'PHOG 98',
#  'PHOG 99',
#  'PHOG 100',
#  'PHOG 101',
#  'PHOG 102',
#  'PHOG 103',
#  'PHOG 104',
#  'PHOG 105',
#  'PHOG 106',
#  'PHOG 107',
#  'PHOG 108',
#  'PHOG 109',
#  'PHOG 110',
#  'PHOG 111',
#  'PHOG 112',
#  'PHOG 113',
#  'PHOG 114',
#  'PHOG 115',
#  'PHOG 116',
#  'PHOG 117',
#  'PHOG 118',
#  'PHOG 119',
#  'PHOG 120',
#  'PHOG 121',
#  'PHOG 122',
#  'PHOG 123',
#  'PHOG 124',
#  'PHOG 125',
#  'PHOG 126',
#  'PHOG 127',
#  'PHOG 128',
#  'PHOG 129',
#  'PHOG 130',
#  'PHOG 131',
#  'PHOG 132',
#  'PHOG 133',
#  'PHOG 134',
#  'PHOG 135',
#  'PHOG 136',
#  'PHOG 137',
#  'PHOG 138',
#  'PHOG 139',
#  'PHOG 140',
#  'PHOG 141',
#  'PHOG 142',
#  'PHOG 143',
#  'PHOG 144',
#  'PHOG 145',
#  'PHOG 146',
#  'PHOG 147',
#  'PHOG 148',
#  'PHOG 149',
#  'PHOG 150',
#  'PHOG 151',
#  'PHOG 152',
#  'PHOG 153',
#  'PHOG 154',
#  'PHOG 155',
#  'PHOG 156',
#  'PHOG 157',
#  'PHOG 158',
#  'PHOG 159',
#  'PHOG 160',
#  'PHOG 161',
#  'PHOG 162',
#  'PHOG 163',
#  'PHOG 164',
#  'PHOG 165',
#  'PHOG 166',
#  'PHOG 167',
#  'PHOG 168',
#  'PHOG 169',
#  'PHOG 170',
#  'PHOG 171',
#  'PHOG 172',
#  'PHOG 173',
#  'PHOG 174',
#  'PHOG 175',
#  'PHOG 176',
#  'PHOG 177',
#  'PHOG 178',
#  'PHOG 179',
#  'PHOG 180',
#  'PHOG 181',
#  'PHOG 182',
#  'PHOG 183',
#  'PHOG 184',
#  'PHOG 185',
#  'PHOG 186',
#  'PHOG 187',
#  'PHOG 188',
#  'PHOG 189',
#  'PHOG 190',
#  'PHOG 191',
#  'PHOG 192',
#  'PHOG 193',
#  'PHOG 194',
#  'PHOG 195',
#  'PHOG 196',
#  'PHOG 197',
#  'PHOG 198',
#  'PHOG 199',
#  'PHOG 200',
#  'PHOG 201',
#  'PHOG 202',
#  'PHOG 203',
#  'PHOG 204',
#  'PHOG 205',
#  'PHOG 206',
#  'PHOG 207',
#  'PHOG 208',
#  'PHOG 209',
#  'PHOG 210',
#  'PHOG 211',
#  'PHOG 212',
#  'PHOG 213',
#  'PHOG 214',
#  'PHOG 215',
#  'PHOG 216',
#  'PHOG 217',
#  'PHOG 218',
#  'PHOG 219',
#  'PHOG 220',
#  'PHOG 221',
#  'PHOG 222',
#  'PHOG 223',
#  'PHOG 224',
#  'PHOG 225',
#  'PHOG 226',
#  'PHOG 227',
#  'PHOG 228',
#  'PHOG 229',
#  'PHOG 230',
#  'PHOG 231',
#  'PHOG 232',
#  'PHOG 233',
#  'PHOG 234',
#  'PHOG 235',
#  'PHOG 236',
#  'PHOG 237',
#  'PHOG 238',
#  'PHOG 239',
#  'PHOG 240',
#  'PHOG 241',
#  'PHOG 242',
#  'PHOG 243',
#  'PHOG 244',
#  'PHOG 245',
#  'PHOG 246',
#  'PHOG 247',
#  'PHOG 248',
#  'PHOG 249',
#  'PHOG 250',
#  'PHOG 251',
#  'PHOG 252',
#  'PHOG 253',
#  'PHOG 254',
#  'PHOG 255',
#  'PHOG 256',
#  'PHOG 257',
#  'PHOG 258',
#  'PHOG 259',
#  'PHOG 260',
#  'PHOG 261',
#  'PHOG 262',
#  'PHOG 263',
#  'PHOG 264',
#  'PHOG 265',
#  'PHOG 266',
#  'PHOG 267',
#  'PHOG 268',
#  'PHOG 269',
#  'PHOG 270',
#  'PHOG 271',
#  'PHOG 272',
#  'PHOG 273',
#  'PHOG 274',
#  'PHOG 275',
#  'PHOG 276',
#  'PHOG 277',
#  'PHOG 278',
#  'PHOG 279',
#  'PHOG 280',
#  'PHOG 281',
#  'PHOG 282',
#  'PHOG 283',
#  'PHOG 284',
#  'PHOG 285',
#  'PHOG 286',
#  'PHOG 287',
#  'PHOG 288',
#  'PHOG 289',
#  'PHOG 290',
#  'PHOG 291',
#  'PHOG 292',
#  'PHOG 293',
#  'PHOG 294',
#  ...]

# %%
plt.hist(movs_length,np.arange(0,240000,2000),label="hst")
plt.gca().set_yscale('log')
plt.show()

# %%
ranges = loadRange()
pca = loadPCA(ranges)

# %%
component = pca.components_
eigens = pca.explained_variance_
eigenratio = pca.explained_variance_ratio_

# %%
print(ranges)
# Out:
# [[  5.00000000e-02   4.65053763e-02   4.36672968e-02 ...,   2.62850000e+02
#     3.35050000e+02   2.92000000e+02]
#  [  9.50000000e-01   8.83602151e-01   8.29678639e-01 ...,   2.31215000e+03
#     3.28795000e+03   2.59600000e+03]]

# %%
print(eigenratio.tolist()[:30])
# Out:
# [0.19046600453145254, 0.10418561944117845, 0.08991178903772701, 0.06988497541340548, 0.04642803589432593, 0.04098096972689149, 0.033655542946007505, 0.03011473427537491, 0.026031388598253952, 0.020426107901711843, 0.017458867173930012, 0.013825212723337102, 0.011867732225081978, 0.010908678827489516, 0.010050571648483128, 0.009363170861342399, 0.008660843204274557, 0.007536844578114386, 0.006842806418077072, 0.006362593580447671, 0.006066458290562876, 0.005643989369139039, 0.005372132695938067, 0.005273903415115154, 0.005117916679800234, 0.004689367432850034, 0.004434204593135072, 0.004188900622277559, 0.003946165053737731, 0.0037851649742984155]

# %%
print(sum(eigenratio[:100]))
# Out:
# 0.907850410557

# %%
feature_names = featureNames()
component = component[:50,:]
pt = np.max(np.abs(component),0)
ptall = np.max(np.abs(component))
throw = pt < (ptall*0.01)
throwindex = np.arange(0,2655)[throw]
throwfeature = np.array(feature_names)[throw]

fr = np.vstack((pt/ptall,feature_names))

print(len(throwindex))
print(fr[:,2631:2635])
#print(throwindex+1)
#print(throwfeature)
# Out:
# 762
# [['0.00427090682512' '0.00053754073893' '0.000105159648332'
#   '7.57590810223e-05']
#  ['Erraticity 1' 'Erraticity 2' 'Erraticity 3' 'Erraticity 4']]

# %%
print(movs[23472])
idddd = movs[23472][0]
pcatransformed = np.load("/afs/inf.ed.ac.uk/group/ug4-projects/s1413557/features/0/0f/"+idddd+".pcaFeature.npy")
# Out:
# ['0f13ebb537ca30244623586a5faad81b#201108241230' '38' '1']

# %%
asd = pd.DataFrame(pcatransformed)
asd.describe()
# Out:
#                 0            1            2            3            4   \
# count  5988.000000  5988.000000  5988.000000  5988.000000  5988.000000
# mean     -0.531499    -0.611799    -1.220866     0.200187    -0.637263
# std       3.405892     2.017961     1.290732     1.567868     1.170864
# min      -4.854966    -4.937241    -4.877994    -3.901056    -4.615034
# 25%      -3.473433    -1.984418    -2.025675    -0.965033    -1.426102
# 50%      -2.005199    -0.967034    -1.258780    -0.302438    -0.563655
# 75%       2.376680     0.429735    -0.469512     1.271378     0.213195
# max       6.649833     6.725243     5.368467     5.619388     3.404382
#
#                 5            6            7            8            9   \
# count  5988.000000  5988.000000  5988.000000  5988.000000  5988.000000
# mean     -0.499491    -0.107724     0.086304    -0.138881     0.101023
# std       1.112636     0.975522     1.063756     0.816666     0.963616
# min      -4.304048    -3.128237    -3.658968    -2.299950    -2.492004
# 25%      -1.207381    -0.619826    -0.536219    -0.683299    -0.614196
# 50%      -0.630275     0.002319     0.311926    -0.310218     0.073128
# 75%       0.082290     0.415592     0.826348     0.255632     0.834581
# max       4.127459     4.243876     3.213175     4.532563     3.422756
#
#           ...                90           91           92           93  \
# count     ...       5988.000000  5988.000000  5988.000000  5988.000000
# mean      ...          0.002392    -0.026374    -0.015258     0.003632
# std       ...          0.146018     0.157807     0.177204     0.177380
# min       ...         -0.648195    -0.623171    -0.750269    -0.695966
# 25%       ...         -0.093087    -0.135492    -0.125134    -0.113633
# 50%       ...         -0.004832    -0.026891    -0.016926     0.008182
# 75%       ...          0.097826     0.077397     0.086668     0.125280
# max       ...          0.602124     0.683806     0.878653     0.681109
#
#                 94           95           96           97           98  \
# count  5988.000000  5988.000000  5988.000000  5988.000000  5988.000000
# mean     -0.017224     0.001578    -0.006410    -0.036753     0.001536
# std       0.172141     0.133363     0.145921     0.171594     0.148151
# min      -0.711816    -0.641212    -0.556148    -0.687554    -0.603685
# 25%      -0.131503    -0.084903    -0.101543    -0.147515    -0.091563
# 50%      -0.030975     0.000221    -0.007593    -0.022908    -0.001810
# 75%       0.087344     0.082124     0.088375     0.083432     0.096487
# max       0.719882     0.641649     0.563306     0.631414     0.886331
#
#                 99
# count  5988.000000
# mean     -0.034567
# std       0.124975
# min      -0.760095
# 25%      -0.108442
# 50%      -0.031262
# 75%       0.042819
# max       1.037766
#
# [8 rows x 100 columns]

# %% [markdown]
# # Timetest

# %%
#Placeholder tookit
time = datetime.now()
print("Took total of {0}".format(datetime.now() - time))
time = datetime.now()
# Out:
# Took total of 0:00:00.000131

# %%
time = datetime.now()
for picker in range(frames):
    if hasContour[picker]:
        image1 = clip[picker]
        thiscontour = getContour(contour[picker])
        mask = np.full(image1.shape, 0, dtype=np.uint8)
        cv2.fillPoly(mask, np.array([thiscontour], dtype=np.int32), (255,)*3)
        image2 = cv2.cvtColor(image1,cv2.COLOR_RGB2YUV)
        image3 = normalizeRGB(image2)[:,:,0]
        image4 = cv2.bitwise_or(cv2.bitwise_not(mask),image1)
        image5 = cv2.cvtColor(image4,cv2.COLOR_RGB2YUV)
        image6 = normalizeRGB(image5)[:,:,0]
        image7 = cv2.bitwise_and(mask,image1)
        image8 = cv2.cvtColor(image7,cv2.COLOR_RGB2YUV)
        image9 = normalizeRGB(image8)[:,:,0]
    print("Image {1} took total of {0}".format(datetime.now() - time,picker+1),end='\r')
print("Took total of {0}              ".format(datetime.now() - time))
# Out:
# Image 894 took total of 0:00:00.203231
# Took total of 0:00:03.539000

# %% [markdown]
# # Testing Algs Output
# ---

# %%
#not very useful

def imageSame(image1,image2,offset=0):
    lowerBound = image2 - np.full(image2.shape,offset)
    upperBound = image2 + np.full(image2.shape,offset)
    result = np.logical_and(image1>=lowerBound,image1<=upperBound)
    return np.sum(result)

def metricRepeating(clip,ras=True):
    if len(clip)<10:
        return 0
    
    scores = []
    for i in np.arange(0,10):
        for j in np.arange(i+1,10):
            scores.append(imageSame(clip[i],clip[j]))
    if ras:
        return np.sqrt(np.average(np.power(scores,2)))
    else:
        return np.average(scores)

# %%
matt_features = getMattFeatures(info, clip, hasContour, contour, fish_id, print_info=True, ret_normalized_erraticity=False)
# Out:
# Calculate 2 feature took total of 0:00:00.105477
# 116 out of 118 feature not calculated

# %%
print(matt_features.shape)
# Out:
# (118, 29)

# %%
path = '/afs/inf.ed.ac.uk/group/ug4-projects/s1413557/line107340.txt'
if os.name == "nt":
    path = 'E:/line107340.txt'
plotContourFromOriginalFile(path,limit_amount=20, add_milk=False)

# %%
picker = 177
showTransformedImage(picker, clip, hasContour, contour)

# %%
printCNNweight()

# %%
printCameras()
# Out:
# 37,1,'NPP-3','3.6mm F1.8 1/3 inches CCD',0,5
# 38,3,'NPP-3','3.6mm F1.8 1/3 inches CCD',0,5
# 39,4,'NPP-3','3.6mm F1.8 1/3 inches CCD',0,5
# 40,1,'HoBiHu','3.6mm F1.8 1/3 inches CCD',0,5
# 41,2,'HoBiHu','3.6mm F1.8 1/3 inches CCD',0,5
# 42,2,'NPP-3','3.6mm F1.8 1/3 inches CCD',0,5
# 43,3,'HoBiHu','3.6mm F1.8 1/3 inches CCD',0,5
# 44,1,'LanYu','3.6mm Iris:auto 1/3 inches CCD; white LED night sight',0,15
# 46,2,'LanYu','3.6mm Iris:auto 1/3 inches CCD; white LED night sight',0,15

# %%
movs = loadMovids()
time = datetime.now()
for i in range(1584):
    __, clip2, __, __, __, __ = loadVideo(movs[i],print_info=False,print_time=True)
    print("Checked Video: {0}  ID: {1}, took: {2}".format(i, movs[i][0],datetime.now()-time), end='\r')
# Out:
# Checked Video: 186  ID: 00219b781e26ae27550f7ebd97343527#201203101720, took: 0:02:16.393160

# %%
picker = 5
picker2 = 177
printSeperateFish(picker,picker2)

# %%
# Took a total of 0:18:53.200900           
# FEIF return 467977 true
# FEIF return 2801786 false
# total of 0 detection have no contour
# Will took about 80 hours to finish all.

reject = 467977
kept = 2801786
no_contour = 0
summu = reject+kept+no_contour
print("Maybe we only need to calculate {0:.3f}% of the features.".format(100.0*kept/summu))
print("Rejected {0:.3f}% of the features.".format(100.0*reject/summu))
print("{0:.3f}% of the features have no Contour.".format(100.0*no_contour/summu))
# Out:
# Maybe we only need to calculate 85.688% of the features.
# Rejected 14.312% of the features.
# 0.000% of the features have no Contour.

# %%
def secToTime(seconds, mode = "full"):
    days = int(seconds // 86400)
    seconds = seconds % 86400
    hours = int(seconds // 3600)
    seconds = seconds % 3600
    minutes = int(seconds // 60)
    seconds = int(seconds % 60)
    if mode == "hour":
        return " {0} Hours".format(24*days+hours)
    return " {0} Days {1} Hours {2} Minute {3} Seconds".format(days,hours,minutes,seconds)

# %%
total_features = 839000000
feif_reduction_rate = 0.66272
videos = 396901

qiqi_time_find_track = 19.2
qiqi_time_extraction = 110.1 
qiqi_time_image_preprocess = 70.0
qiqi_total = qiqi_time_find_track + qiqi_time_extraction + qiqi_time_image_preprocess
qiqi_core_used = 32 #32 out of 40
qiqi_core_used_minimal = 8 #If core is poorly utilized
qiqi_feature_used = 961
qiqi_videos = 455993

my_time_find_track = 0.509453
my_time_extraction = 37 * 60 + 22.1
my_time_image_preprocess = 6.751748
my_total = my_time_find_track + my_time_extraction + my_time_image_preprocess
my_core_used = 1
my_core_used_maximal = 2
my_feature_used = 4716
my_feature_used_actual = 4103

used_total = qiqi_total
used_total2 = my_total

print("Qiqi's calculated runtime using original code (32 core):")
print(secToTime(used_total*qiqi_videos, mode="hour"))
print(secToTime(used_total*qiqi_videos))

print("\nQiqi's calculated runtime using original code (32 core) (corrected total):")
print(secToTime(used_total/qiqi_feature_used*total_features, mode="hour"))
print(secToTime(used_total/qiqi_feature_used*total_features))

print("\nSingle-core Runtime using original code:")
print(secToTime(used_total*qiqi_core_used/qiqi_feature_used*total_features, mode="hour"))
print(secToTime(used_total*qiqi_core_used/qiqi_feature_used*total_features))

print("\n300-core Runtime using original code:")
print(secToTime(used_total*qiqi_core_used/300/qiqi_feature_used*total_features, mode="hour"))
print(secToTime(used_total*qiqi_core_used/300/qiqi_feature_used*total_features))

print("\nMy calculated runtime (1 process, uses about 4*40% = 1.6 core):")
print(secToTime(used_total2/my_feature_used*total_features, mode="hour"))
print(secToTime(used_total2/my_feature_used*total_features))

print("\nMy calculated runtime (reduced with FEIF):")
print(secToTime(used_total2/my_feature_used_actual*total_features*feif_reduction_rate, mode="hour"))
print(secToTime(used_total2/my_feature_used_actual*total_features*feif_reduction_rate))

print("\n300-core runtime using my code:")
print(secToTime(used_total2/300*my_core_used/my_feature_used_actual*total_features*feif_reduction_rate, mode="hour"))
print(secToTime(used_total2/300*my_core_used/my_feature_used_actual*total_features*feif_reduction_rate))

print("\n300-core runtime using my code (worst-case: 2 process per machine):")
print(secToTime(used_total2/300*my_core_used_maximal/my_feature_used_actual*total_features*feif_reduction_rate, mode="hour"))
print(secToTime(used_total2/300*my_core_used_maximal/my_feature_used_actual*total_features*feif_reduction_rate))

print("\nMy process's average runtime per feature:")
print(my_total/my_feature_used_actual)
# Out:
# Qiqi's calculated runtime using original code (32 core):
#  25244 Hours
#  1051 Days 20 Hours 16 Minute 44 Seconds
#
# Qiqi's calculated runtime using original code (32 core) (corrected total):
#  48332 Hours
#  2013 Days 20 Hours 57 Minute 27 Seconds
#
# Single-core Runtime using original code:
#  1546654 Hours
#  64443 Days 22 Hours 38 Minute 31 Seconds
#
# 300-core Runtime using original code:
#  5155 Hours
#  214 Days 19 Hours 30 Minute 55 Seconds
#
# My calculated runtime (1 process, uses about 4*40% = 1.6 core):
#  111159 Hours
#  4631 Days 15 Hours 3 Minute 34 Seconds
#
# My calculated runtime (reduced with FEIF):
#  84673 Hours
#  3528 Days 1 Hours 26 Minute 35 Seconds
#
# 300-core runtime using my code:
#  282 Hours
#  11 Days 18 Hours 14 Minute 41 Seconds
#
# 300-core runtime using my code (worst-case: 2 process per machine):
#  564 Hours
#  23 Days 12 Hours 29 Minute 22 Seconds
#
# My process's average runtime per feature:
# 0.548223543992

# %% [markdown]
# # Windows Test Code below, cuz no library loves windows.

# %%
f4k_features = np.load("C:\Users\YuJianmeng\Desktop\\000091a58183e0358d5c3f8716c8491a#201101151720.f4kfeature.npy")
matt_features = np.load("C:\Users\YuJianmeng\Desktop\\000091a58183e0358d5c3f8716c8491a#201101151720.mattfeature.npy")
feif_mask = np.load("C:\Users\YuJianmeng\Desktop\\000091a58183e0358d5c3f8716c8491a#201101151720.feif.npy")
features = np.column_stack((f4k_features,matt_features))

# %%
pdFeatures = pd.DataFrame(features)
pdFeatures.describe()
# Out:
#               0            1            2            3            4     \
# count  4716.000000  4716.000000  4716.000000  4716.000000  4716.000000
# mean      0.047761     0.004730     0.005602     0.006380     0.008325
# std       0.158739     0.015063     0.016333     0.017598     0.021635
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.000000     0.000000     0.000000     0.000000     0.000000
# 50%       0.000000     0.000000     0.000000     0.000000     0.000000
# 75%       0.002268     0.000000     0.000000     0.002320     0.005452
# max       0.916129     0.178082     0.171642     0.214286     0.295455
#
#               5            6            7            8            9     \
# count  4716.000000  4716.000000  4716.000000  4716.000000  4716.000000
# mean      0.011507     0.017112     0.026748     0.043515     0.067123
# std       0.026509     0.036185     0.050325     0.071256     0.090752
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.000000     0.000000     0.000000     0.000000     0.000000
# 50%       0.000000     0.000000     0.000000     0.005845     0.021610
# 75%       0.010506     0.017805     0.031843     0.061407     0.112274
# max       0.373913     0.437500     0.517241     0.516129     0.558824
#
#           ...              2645         2646         2647         2648  \
# count     ...       4716.000000  4716.000000  4716.000000  4716.000000
# mean      ...       1377.132952   476.085666  1424.459924   455.829729
# std       ...        772.806095   239.856302   819.512998   274.686283
# min       ...          0.000000     0.000000     0.000000     0.000000
# 25%       ...        968.000000   367.750000   980.000000   312.000000
# 50%       ...       1402.000000   502.000000  1433.000000   437.000000
# 75%       ...       1817.000000   634.000000  1892.000000   599.000000
# max       ...       5619.000000  1132.000000  6129.000000  1642.000000
#
#               2649         2650         2651         2652         2653  \
# count  4716.000000  4716.000000  4716.000000  4716.000000  4716.000000
# mean   1351.825488   544.440204  1530.262723   739.238974   772.665818
# std     771.661224   346.217531   843.367173   457.455999   421.512308
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%     931.750000   351.000000  1095.000000   479.000000   571.000000
# 50%    1368.000000   512.500000  1571.500000   703.000000   785.000000
# 75%    1797.000000   716.000000  2025.250000   976.250000  1022.000000
# max    5614.000000  2024.000000  5872.000000  2554.000000  2977.000000
#
#               2654
# count  4716.000000
# mean    840.651612
# std     533.210618
# min       0.000000
# 25%     516.750000
# 50%     801.000000
# 75%    1127.250000
# max    2856.000000
#
# [8 rows x 2655 columns]

# %%
if os.name == "nt":    
    import matlab.engine
    eng = matlab.engine.start_matlab()
    eng.addpath(r'C:/Users/YuJianmeng/f4k/matt-msc/workspace/f4k/fish_recog',nargout=0)

# %%
if os.name == "nt":
    
    i = 0
    thiscontour = getContour(contour[i])
    mask = np.full(image.shape, 0, dtype=np.uint8)
    cv2.fillPoly(mask, np.array([thiscontour], dtype=np.int32), (255,)*3)
    image = clip[i]

    eng.workspace['A'] = image.tolist()
    print(len(image.tolist()))

    (c,d) = eng.generateFeatureFromPython(image.reshape(1,-1).tolist(),full_fish.reshape(1,-1).tolist(),nargout=2)

    print(np.array(c,dtype="double").shape)

# %%
if os.name == "nt":
    eng.exit()
    eng.quit()
    del eng

# %% [markdown]
# # Below code only work on DICE. (#JustPyMatlabThings)

# %%
if os.name != "nt":
    import pymatlab
    session = pymatlab.session_factory('matlab -nodisplay')
    session.run('cd /afs/inf.ed.ac.uk/user/s14/s1413557/f4k-2017-msc-master/matt-msc/workspace/f4k/fish_recog')

# %%
if os.name != "nt" and False:
    #Outdated
    time = datetime.now()
    for i in range(4716):
        thisContour = np.int32([getContour(contour[i])])
        image = clip[i]
        full_fish = np.full((100,100), 0, dtype=np.uint8)
        cv2.fillPoly(full_fish, thisContour, (255,))
        session.putvalue('A',image)
        session.putvalue('B',full_fish)
        session.run('[C, D] = feature_generateFeatureVector(A,B,false)')
        c = session.getvalue('C')
        #d = session.getvalue('D')
        print("Process {0} image took {1}".format(i,datetime.now() - time), end='\r')
    print("Took a total of {0}           ".format(datetime.now() - time) )

# %%
time = datetime.now()

hasCL = np.sum(hasContour)
rgbImgs = [None]*hasCL
binImgs = [None]*hasCL
index = 0
for i in range(frames):
    if hasContour[i]:
        rgbImgs[index]=clip[i]
        binImgs[index]=np.full((100,100), 0, dtype=np.uint8)
        thisContour = np.int32([getContour(contour[i])])
        cv2.fillPoly(binImgs[index], thisContour, (255,))
        index += 1
        
print("Took a total of {0}           ".format(datetime.now() - time) )
session.putvalue('A',rgbImgs)
session.putvalue('B',binImgs)
print("Took a total of {0}           ".format(datetime.now() - time) )

session.run('C = feature_batchGenerateFeatureVector(A,B)')
print("Took a total of {0}           ".format(datetime.now() - time) )
c = session.getvalue('C')
print("Took a total of {0}           ".format(datetime.now() - time) )
# Out:
# Took a total of 0:00:00.340644
# Took a total of 0:00:02.209818
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-11-0c69c559efa6> in <module>()
#      21 session.run("save('nigger')")
#      22
# ---> 23 session.run('C = feature_batchGenerateFeatureVector(A,B)')
#      24 print("Took a total of {0}           ".format(datetime.now() - time) )
#      25 c = session.getvalue('C')
#
# /afs/inf.ed.ac.uk/user/s14/s1413557/miniconda2/envs/hons/lib/python2.7/site-packages/pymatlab/matlab.pyc in run(self, matlab_statement)
#      82         if error_string != "":
#      83             raise(RuntimeError('Error from Matlab: {0}'.format(
# ---> 84                 error_string)))
#      85
#      86     def getvalue(self,variable):
#
# RuntimeError: Error from Matlab: Error: MATLAB:UndefinedFunction with message: Undefined function 'feature_batchGenerateFeatureVector' for input arguments of type 'uint8'.

# %%
print(c.shape)
# Out:
# (2626,)

# %%
if os.name != "nt":
    del session

# %% [markdown]
# ---
